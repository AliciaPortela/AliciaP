# %% [markdown]
# Exam_2_Answers
#
# First of all, I am connecting to the SqlMagic, through the command below:

# %%
# %load_ext sql
#%config SqlMagic.autocommit=False
# %sql mysql+pymysql://root:root@127.0.0.1:3306/mysql
# Out:
# 'Connected: root@mysql'

# %% [markdown]
# Then, I am going to open the files I was given. For open and read them, I use the command 'open' and as arguments, the name of the files and "r", which is only for reading it. Then, I printed the content of the files with the command file.read() to see the content inside them.

# %%
germplasm_table = open("Germplasm.tsv", "r") #I am opening the germplasm.tsv file only for reading "r"
print(germplasm_table.read()) #printing the content of that table
locusgene_table = open("LocusGene.tsv", "r") #I am opening the LocusGene.tsv file only for reading "r"
print(locusgene_table.read()) #printing the content of that table
# Out:
# Locus	germplasm	phenotype	pubmed
# AT1G01040	CS3828	Increased abundance of miRNA precursors.	17369351
# AT1G01060	lhy-101	The mutant plants are hypersensitive to both FRc and Rc light treatments in hypocotyl elongation and exhibits a small reciprocal enlargement in cotyledon area, albeit not statistically significant.	16891401
# AT1G01140	SALK_058629	hypersensitive to low potassium media	17486125
# AT1G01220	SALK_012400C	fkgp-1 mutants have about 40 times more L-fucose than wild type Arabidopsis plants, but the levels of other monosaccharides do not appear to differ significantly in the mutants. No obvious phenotypic abnormalities were observed in the fkgp-1 mutants, nor were any differences in the sugar composition of cell wall polysaccharides detected.	18199744
# AT2G03720	SALK_042433	Multiple straight hairs	16367956
# AT2G03800	gek1-1	Ethanol hypersensitivity.	15215505
# ...

# %% [markdown]
# PROBLEM 1
#
# To do this problem, I am doing a loop for reading the lines of each o the tables with the function readlines(). For each line starting from line 2, in any of the tables, I want to match a regular expression that corresponds to the pattern ATxGxxxxxx. If there is a match, it will print the AGI code of each table.
#
# Then, for assure that the AGI code follows the same sequence in both tables, i asked if the first column of the germplasm table (the AGI_germplasm object) was equal (==) to the first column of the locusgene table (the AGI_locusgene object). And the output was 'true', so the lines of data in Germplasm.tsv, and LocusGene.tsv are follow the same sequence, based on the AGI Locus Code.
#
# The code is below:

# %%
import re   #to do the re.search



germplasm_table.seek(0) #set the reading back to the beggining of the table 

#now I am iterating to obtain only the first column of the germplasm table 
for line in germplasm_table.readlines()[2:34]: #for each line read by readlines() in germplasm table. I specify that only want to read from lines 2 to 34 (because the first one is the header)
    matchObj = re.search( r'(\b[A-Z]{2}\w[A-Z]\w*\t)', line)  #match this regular expression, which corresponds to the search of ATxGxxxxxx AGI Locus Code
    if matchObj: #if there is a match
        AGI_germplasm = matchObj.group() #create an object with the matches 
        print(AGI_germplasm) #print the object 
    else: #otherwise
        print ("No match!!") #print no match 
 
 
locusgene_table.seek(0) #set the reading back to the beggining of the table 

#now I am iterating to obtain only the first column of the locusgene table 
for line in locusgene_table.readlines()[2:34]: #for each line read by readlines() in locusgene table. I specify that only want to read from lines 2 to 34 (because the first one is the header)
    matchObj = re.search( r'(\b[A-Z]{2}\w[A-Z]\w*\t)', line)  #match this regular expression, which corresponds to the search of ATxGxxxxxx AGI Locus Code
    if matchObj: #if there is a match
        AGI_locusgene = matchObj.group() #create an object with the matches 
        print(AGI_locusgene) #print the object 
    else: #otherwise
        print ("No match!!") #print no match 

    
AGI_germplasm == AGI_locusgene #are the matches of germplasm table (i.e. the AGI codes) equal to the matches of the locusgene table (i.e. the AGI codes)?
# Out:
# AT1G01060
# AT1G01140
# AT1G01220
# AT2G03720
# AT2G03800
# AT2G04240
# AT2G05210
# AT3G02130
# AT3G02140
# AT3G02230
# AT3G02260
# AT3G02310
# AT3G02680
# AT3G02850
# AT3G02870
# AT3G03260
# AT4G14790
# AT4G15210
# AT4G15560
# AT4G15570
# AT4G15802
# AT4G15880
# AT4G16420
# AT4G16480
# AT5G10480
# AT5G10510
# AT5G11110
# AT5G11260
# AT5G11510
# AT5G12200
# AT5G13290
# AT1G01060
# AT1G01140
# AT1G01220
# AT2G03720
# AT2G03800
# AT2G04240
# AT2G05210
# AT3G02130
# AT3G02140
# AT3G02230
# AT3G02260
# AT3G02310
# AT3G02680
# AT3G02850
# AT3G02870
# AT3G03260
# AT4G14790
# AT4G15210
# AT4G15560
# AT4G15570
# AT4G15802
# AT4G15880
# AT4G16420
# AT4G16480
# AT5G10480
# AT5G10510
# AT5G11110
# AT5G11260
# AT5G11510
# AT5G12200
# AT5G13290
# True

# %% [markdown]
# PROBLEM 2
#
# I am using sqlMagic for this problem.
#
# First of all, I create the database called 'germplasms'. Then, I make sure that it's already created with the show databases command. Then, I use the command use germplasms to make sure that all of the following commands go to the germplasms database.
#
# Once I have the germplasms database created, I create the 2 tables, each of them for each of the 2 files we are using. One table is called 'germplasm', which corresponds to the Germplasm.tsv file, and has 4 columns, which headers are locus, germplasm, phenotype and pubmed, respectively; and the other is called 'locusgene', which corresponds to LocusGene.tsv file, and has 3 columns, which headers are locus, gene and protein length, respectively. As the AGI locus code are the same both in germplasm table and locusgene table, I am going to use it as a primary key, intead of inserting an id for each record.
#
# Once the tables are created I must join them. How? I am joining them saying that the values og the locus column in germplasm table are the same as those in the locus column in locusgene table. And that's how the two tables are linked in a 1:1 relationship.
#
# The code is as follows...
#
# Note that I've written the command drop table just in case dropping them was necessary to correct some mistake.

# %%
#create database
# %sql create database germplasms; #to create the database where I am going to store the 2 datasets 
# %sql show databases;
# %sql use germplasms;

#create tables
# %sql CREATE TABLE germplasm (locus VARCHAR(100) NOT NULL PRIMARY KEY, germplasm VARCHAR(100) NOT NULL, phenotype VARCHAR(1000) NOT NULL, pubmed INTEGER NOT NULL);
# %sql DESCRIBE germplasm;
# %sql CREATE TABLE locusgene (locus VARCHAR(100) NOT NULL PRIMARY KEY, gene VARCHAR(100) NOT NULL, protein_length INTEGER NOT NULL)
# %sql DESCRIBE locusgene

# %sql show tables;

#Every germplasm has a gene record. This is a 1:1 relationship.
#So every locus at the germplasm table must point to the locus of the locusgene table
#We need to connect the germplasm table locus to the appropriate locus from the locusgene table. Joinning tables
# %sql SELECT * FROM germplasm, locusgene WHERE germplasm.locus = locusgene.locus;

#%sql drop table germplasm
#%sql drop table locusgene
#%sql show tables;
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/mysql
# 0 rows affected.
#  * mysql+pymysql://root:***@127.0.0.1:3306/mysql
# 3 rows affected.
#  * mysql+pymysql://root:***@127.0.0.1:3306/mysql
# 2 rows affected.
# [('germplasm',), ('locusgene',)]

# %% [markdown]
# PROBLEM 3
#
# In this problem I am connecting to the database through Python, rather than sqlMagic. I am connecting using the stablished code, specifying what database I want to use.
#
# Then, I insert the data into the germplasm table, one row by one, through the command INSERT INTO.
#
# And I do the same thing with the locusgene table, following the same process.
#
# Finally I have to be sure that data has been introducted correctly into two tables. For see the content of each table, I use the command select * (select everything) from any of the two tables.
# I use the fetchall() method in order to obtain a list containing all of the elements of these two tables, which I pass into an object called results and I printed it to see each list. So, each table is represented as a list of dictionaries, and each of the dictionaries represents a record inside those tables).
# I use the len() method to know how many elements have each of the lists. Again, I create an object called elements being equal to the length of each list and I printed that element to the screen. In both cases, the lenght of the list is 32. So, on the one hand I am aware now that both tables have the same length, which gives me an idea that data has been introducted correctly. On the other hand, the original files have 33 lines, taking into account the headerline, so 33-1=32 records, which corresponds to the elements of both lists. Therefore, data has been introducted correctly.
#
# NOTE: I know that it would be easier and safer to do a loop for inserting the data into tables. But I tried it with a code and it does not work. For that reason, I chose inserting them manually.

# %%
#fconnection to mySQL through pymysql
import pymysql.cursors
connection = pymysql.connect(host='localhost',
                             user='root',
                             password='root',
                             db='germplasms',
                             charset='utf8mb4',  # note utf8... this is important for unusual characters!
                             cursorclass=pymysql.cursors.DictCursor,
                             #autocommit=True
                            )
connection.autocommit(True)


#pointing to the database germplasms and executing the sql commands 

#inserting data into germplasm table, using the sql command INSET INTO followed by the columns and followed by the values that are being inserted into those columns 

try:
    with connection.cursor() as cursor:
            
            sql = "INSERT INTO germplasm (locus, germplasm, phenotype, pubmed) VALUES ('AT1G01040', 'CS3828', 'Increased abundance of miRNA precursors.', 17369351)"
            cursor.execute(sql)  
            sql = "INSERT INTO germplasm (locus, germplasm, phenotype, pubmed) VALUES ('AT1G01060', 'lhy-101', 'The mutant plants are hypersensitive to both FRc and Rc light treatments in hypocotyl elongation and exhibits a small reciprocal enlargement in cotyledon area, albeit not statistically significant.', 16891401)"
            cursor.execute(sql) 
            sql = "INSERT INTO germplasm (locus, germplasm, phenotype, pubmed) VALUES ('AT1G01140', 'SALK_058629', 'hypersensitive to low potassium media', 17486125)"
            cursor.execute(sql) 
            sql = "INSERT INTO germplasm (locus, germplasm, phenotype, pubmed) VALUES ('AT1G01220', 'SALK_012400C', 'fkgp-1 mutants have about 40 times more L-fucose than wild type Arabidopsis plants, but the levels of other monosaccharides do not appear to differ significantly in the mutants. No obvious phenotypic abnormalities were observed in the fkgp-1 mutants, nor were any differences in the sugar composition of cell wall polysaccharides detected.', 18199744)"
            cursor.execute(sql)  
            sql = "INSERT INTO germplasm (locus, germplasm, phenotype, pubmed) VALUES ('AT2G03720', 'SALK_042433', 'Multiple straight hairs', 16367956)"
            cursor.execute(sql)     
            sql = "INSERT INTO germplasm (locus, germplasm, phenotype, pubmed) VALUES ('AT2G03800', 'gek1-1', 'Ethanol hypersensitivity.', 15215505)"
            cursor.execute(sql)   
            sql = "INSERT INTO germplasm (locus, germplasm, phenotype, pubmed) VALUES ('AT2G04240', 'xerico', 'Resistant to exogenous ABA. Seeds contained lower amounts of endogenous ABA than wildtype.', 17933900)"
            cursor.execute(sql) 
            sql = "INSERT INTO germplasm (locus, germplasm, phenotype, pubmed) VALUES ('AT2G05210', 'pot1-1', 'No visible phenotype.', 17627276)"
            cursor.execute(sql) 
            sql = "INSERT INTO germplasm (locus, germplasm, phenotype, pubmed) VALUES ('AT3G02130', 'rpk2-2', 'The homozygous progeny is indistinguishable from wild-type plants during vegetative growth but showed several morphological alterations after bolting. These plants displayed enhanced inflorescence branching and formed three times as many siliques and flowers as did wild-type plants.', 17419837)"
            cursor.execute(sql) 
            sql = "INSERT INTO germplasm (locus, germplasm, phenotype, pubmed) VALUES ('AT3G02140', 'afp4-1', 'Decreased germination on high concentrations of glucose and sorbitol.', 18484180)"
            cursor.execute(sql) 
            sql = "INSERT INTO germplasm (locus, germplasm, phenotype, pubmed) VALUES ('AT3G02230', 'rgp1-1', 'rgp1-1 mutants have significantly lower levels of UDP-L-arabinose mutase activity compared to wild-type plants and significantly lower levels of arabinose in their cell walls.', 21478444)"
            cursor.execute(sql) 
            sql = "INSERT INTO germplasm (locus, germplasm, phenotype, pubmed) VALUES ('AT3G02260', 'tir3-1 RGLG1:rglg1 rglg2', 'The triple homozygous progeny has low viability, accumulated anthocyanin, and all plants died before shoot emergence.', 17586653)"
            cursor.execute(sql)             
            sql = "INSERT INTO germplasm (locus, germplasm, phenotype, pubmed) VALUES ('AT3G02310', 'sep2-1', 'Non-described subtle phenotype.', 10821278)"
            cursor.execute(sql) 
            sql = "INSERT INTO germplasm (locus, germplasm, phenotype, pubmed) VALUES ('AT3G02680', 'atnbs1-1', 'Significantly smaller when grown in the presence of methyl methanosulfonate (MMS) with root growth.  Normal growth under standard growth conditions.', 17672843)"
            cursor.execute(sql) 
            sql = "INSERT INTO germplasm (locus, germplasm, phenotype, pubmed) VALUES ('AT3G02850', 'CS3816', 'The skor-1 mutant is sensitive to toxic cations in addition to K+ depletion.', 17568770)"
            cursor.execute(sql) 
            sql = "INSERT INTO germplasm (locus, germplasm, phenotype, pubmed) VALUES ('AT3G02870', 'vtc4-1', 'ascorbate deficient', 16595667)"
            cursor.execute(sql) 
            sql = "INSERT INTO germplasm (locus, germplasm, phenotype, pubmed) VALUES ('AT3G03260', 'hdg8-1', 'No visible phenotype.', 16778018)"
            cursor.execute(sql) 
            sql = "INSERT INTO germplasm (locus, germplasm, phenotype, pubmed) VALUES ('AT4G14790', 'pdd17', 'Defective pollen development.', 19237690)"
            cursor.execute(sql) 
            sql = "INSERT INTO germplasm (locus, germplasm, phenotype, pubmed) VALUES ('AT4G15210', 'bmy1-2', 'Plants cold-shocked for 6h have an increased starch content compared to wildtype.', 16297066)"
            cursor.execute(sql) 
            sql = "INSERT INTO germplasm (locus, germplasm, phenotype, pubmed) VALUES ('AT4G15560', 'cla1-1', 'Mutant seeds grown on medium supplemented with non-phosphorylated synthetic 1-deoxy-D-xylulose (DX) develop green leaves.', 10982425)"
            cursor.execute(sql) 
            sql = "INSERT INTO germplasm (locus, germplasm, phenotype, pubmed) VALUES ('AT4G15570', 'maa3', 'Homozygotes are not recovered. Female gametophyte development is delayed and asynchronous. During fertilization, fusion of polar nuclei does not occur. Polar nuclei nucloeli are smaller than WT.', 18772186)"
            cursor.execute(sql) 
            sql = "INSERT INTO germplasm (locus, germplasm, phenotype, pubmed) VALUES ('AT4G15802', 'Athspb-2', 'Early flowering, reduced fertility, aborted seeds.', 20388662)"
            cursor.execute(sql) 
            sql = "INSERT INTO germplasm (locus, germplasm, phenotype, pubmed) VALUES ('AT4G15880', 'esd4-2', 'Decreased mRNA levels of the floral repressors FLC and MAF4 and increased mRNA levels of the floral activators FT and SOC1.', 17513499)"
            cursor.execute(sql) 
            sql = "INSERT INTO germplasm (locus, germplasm, phenotype, pubmed) VALUES ('AT4G16420', 'prz1-1', 'Altered response to auxin and cytokinin', 12747832)"
            cursor.execute(sql) 
            sql = "INSERT INTO germplasm (locus, germplasm, phenotype, pubmed) VALUES ('AT4G16480', 'atint4-2', 'No visible phenotype.', 16603666)"
            cursor.execute(sql) 
            sql = "INSERT INTO germplasm (locus, germplasm, phenotype, pubmed) VALUES ('AT5G10480', 'pas2-3', 'Segregates 25% embryo lethal.', 18799749)"
            cursor.execute(sql) 
            sql = "INSERT INTO germplasm (locus, germplasm, phenotype, pubmed) VALUES ('AT5G10510', 'plt3-1', 'Short roots and shortened root meristem.', 17960244)"
            cursor.execute(sql) 
            sql = "INSERT INTO germplasm (locus, germplasm, phenotype, pubmed) VALUES ('AT5G11110', 'kns2', 'Defects are specific to pollen exine structure. Smaller mesh size in the exine structure. Increased number of baculae. Fully fertile.', 18779216)"
            cursor.execute(sql) 
            sql = "INSERT INTO germplasm (locus, germplasm, phenotype, pubmed) VALUES ('AT5G11260', 'hy5-101', 'Under FRc conditions, the length mutant hypocotyls is increased compared to that of wild-type plants.  Under Rc conditions, the hypocotyl length is also increased and the cotyledon area is smaller.', 16891401)"
            cursor.execute(sql) 
            sql = "INSERT INTO germplasm (locus, germplasm, phenotype, pubmed) VALUES ('AT5G11510', 'myb3r4-1', 'No visible phenotype.', 17287251)"
            cursor.execute(sql) 
            sql = "INSERT INTO germplasm (locus, germplasm, phenotype, pubmed) VALUES ('AT5G12200', 'pyd2-2', 'The pyd2-2 mutant has a wild-type appearance under normal growth conditions. Pyrimidine nucleotide and uridine levels are not changed in the mutant, but uracil levels are increased. These mutants cannot grow normally when uracil is provided as a sole nitrogen source.', 19413687)"
            cursor.execute(sql) 
            sql = "INSERT INTO germplasm (locus, germplasm, phenotype, pubmed) VALUES ('AT5G13290', 'crn-1', 'Increased meristem size. Vegetative meristems are are 30% larger than wild type. After bolting inflorescence meristems are enlarged and occasionally fasciated. Flowers occasionally produce extra organs in the first 3.', 12345678)"
            cursor.execute(sql) 
            #connection.commit()     
    
finally:
    print("")
    connection.close()

# %%
#now, I am insterting data into locusgene table following the same pattern as before 

connection = pymysql.connect(host='localhost',
                             user='root',
                             password='root',
                             db='germplasms',
                             charset='utf8mb4',  # note utf8... this is important for unusual characters!
                             cursorclass=pymysql.cursors.DictCursor,
                            #autocommit=True
                            )
                            
connection.autocommit(True)


#pointing to the database germplasms and executing the sql commands 

#first, I am inserting data into germplasm table, using the sql command INSET INTO followed by the columns and followed by the values that are being inserted into those columns 

try:
    with connection.cursor() as cursor:
            
            sql = "INSERT INTO locusgene (locus, gene, protein_length) VALUES ('AT1G01040', 'DCL1', 332)"
            cursor.execute(sql) 
            sql = "INSERT INTO locusgene (locus, gene, protein_length) VALUES ('AT1G01060', 'LHY', 290)"
            cursor.execute(sql) 
            sql = "INSERT INTO locusgene (locus, gene, protein_length) VALUES ('AT1G01140', 'CIPK9', 223)"
            cursor.execute(sql) 
            sql = "INSERT INTO locusgene (locus, gene, protein_length) VALUES ('AT1G01220', 'FKGP', 190)"
            cursor.execute(sql)  
            sql = "INSERT INTO locusgene (locus, gene, protein_length) VALUES ('AT2G03720', 'MRH6', 189)"
            cursor.execute(sql)     
            sql = "INSERT INTO locusgene (locus, gene, protein_length) VALUES ('AT2G03800', 'GEK1', 196)"
            cursor.execute(sql)   
            sql = "INSERT INTO locusgene (locus, gene, protein_length) VALUES ('AT2G04240', 'XERICO', 256)"
            cursor.execute(sql) 
            sql = "INSERT INTO locusgene (locus, gene, protein_length) VALUES ('AT2G05210', 'POT1A', 221)"
            cursor.execute(sql) 
            sql = "INSERT INTO locusgene (locus, gene, protein_length) VALUES ('AT3G02130', 'RPK2', 284)"
            cursor.execute(sql) 
            sql = "INSERT INTO locusgene (locus, gene, protein_length) VALUES ('AT3G02140', 'TMAC2', 300)"
            cursor.execute(sql) 
            sql = "INSERT INTO locusgene (locus, gene, protein_length) VALUES ('AT3G02230', 'RGP1', 301)"
            cursor.execute(sql) 
            sql = "INSERT INTO locusgene (locus, gene, protein_length) VALUES ('AT3G02260', 'BIG', 279)"
            cursor.execute(sql)             
            sql = "INSERT INTO locusgene (locus, gene, protein_length) VALUES ('AT3G02310', 'SEP2', 175)"
            cursor.execute(sql) 
            sql = "INSERT INTO locusgene (locus, gene, protein_length) VALUES ('AT3G02680', 'NBS1', 190)"
            cursor.execute(sql) 
            sql = "INSERT INTO locusgene (locus, gene, protein_length) VALUES ('AT3G02850', 'SKOR', 234)"
            cursor.execute(sql) 
            sql = "INSERT INTO locusgene (locus, gene, protein_length) VALUES ('AT3G02870', 'VTC4', 311)"
            cursor.execute(sql) 
            sql = "INSERT INTO locusgene (locus, gene, protein_length) VALUES ('AT3G03260', 'HDG8', 194)"
            cursor.execute(sql) 
            sql = "INSERT INTO locusgene (locus, gene, protein_length) VALUES ('AT4G14790', 'SUV3', 312)"
            cursor.execute(sql) 
            sql = "INSERT INTO locusgene (locus, gene, protein_length) VALUES ('AT4G15210', 'BAM5', 313)"
            cursor.execute(sql) 
            sql = "INSERT INTO locusgene (locus, gene, protein_length) VALUES ('AT4G15560', 'DXS', 219)"
            cursor.execute(sql) 
            sql = "INSERT INTO locusgene (locus, gene, protein_length) VALUES ('AT4G15570', 'MAA3', 294)"
            cursor.execute(sql) 
            sql = "INSERT INTO locusgene (locus, gene, protein_length) VALUES ('AT4G15802', 'HSBP', 254)"
            cursor.execute(sql) 
            sql = "INSERT INTO locusgene (locus, gene, protein_length) VALUES ('AT4G15880', 'ESD4', 265)"
            cursor.execute(sql) 
            sql = "INSERT INTO locusgene (locus, gene, protein_length) VALUES ('AT4G16420', 'ADA2B', 279)"
            cursor.execute(sql) 
            sql = "INSERT INTO locusgene (locus, gene, protein_length) VALUES ('AT4G16480', 'INT4', 284)"
            cursor.execute(sql) 
            sql = "INSERT INTO locusgene (locus, gene, protein_length) VALUES ('AT5G10480', 'PAS2', 301)"
            cursor.execute(sql) 
            sql = "INSERT INTO locusgene (locus, gene, protein_length) VALUES ('AT5G10510', 'AIL6', 310)"
            cursor.execute(sql) 
            sql = "INSERT INTO locusgene (locus, gene, protein_length) VALUES ('AT5G11110', 'SPS2', 232)"
            cursor.execute(sql) 
            sql = "INSERT INTO locusgene (locus, gene, protein_length) VALUES ('AT5G11260', 'HY5', 221)"
            cursor.execute(sql) 
            sql = "INSERT INTO locusgene (locus, gene, protein_length) VALUES ('AT5G11510', 'MYB3R-4', 336)"
            cursor.execute(sql) 
            sql = "INSERT INTO locusgene (locus, gene, protein_length) VALUES ('AT5G12200', 'PYD2', 310)"
            cursor.execute(sql) 
            sql = "INSERT INTO locusgene (locus, gene, protein_length) VALUES ('AT5G13290', 'CRN', 189)" 
            cursor.execute(sql) 
            #connection.commit()       
    
finally:
    print("")
    connection.close()

# %%
#now I am going to check the data has been introduced correctly
#first, I am going to check the content inside germplasm table 

connection = pymysql.connect(host='localhost',
                             user='root',
                             password='root',
                             db='germplasms',
                             charset='utf8mb4',  # note utf8... this is important for unusual characters!
                             cursorclass=pymysql.cursors.DictCursor,
                             #autocommit=True
                            )

connection.autocommit(True)



try:
    with connection.cursor() as cursor:
            
            sql = "SELECT * from germplasm" #it will give all data inside germplasm table
            cursor.execute(sql) 
            results = cursor.fetchall() #cursor fetchall is a list, so the content of the germplasm will be given as a list 
            print(results)
            elements = len(results)
            print(elements)
            #connection.commit()       
    
finally:
    print("")
    connection.close()
# Out:
# [{'locus': 'AT1G01040', 'germplasm': 'CS3828', 'phenotype': 'Increased abundance of miRNA precursors.', 'pubmed': 17369351}, {'locus': 'AT1G01060', 'germplasm': 'lhy-101', 'phenotype': 'The mutant plants are hypersensitive to both FRc and Rc light treatments in hypocotyl elongation and exhibits a small reciprocal enlargement in cotyledon area, albeit not statistically significant.', 'pubmed': 16891401}, {'locus': 'AT1G01140', 'germplasm': 'SALK_058629', 'phenotype': 'hypersensitive to low potassium media', 'pubmed': 17486125}, {'locus': 'AT1G01220', 'germplasm': 'SALK_012400C', 'phenotype': 'fkgp-1 mutants have about 40 times more L-fucose than wild type Arabidopsis plants, but the levels of other monosaccharides do not appear to differ significantly in the mutants. No obvious phenotypic abnormalities were observed in the fkgp-1 mutants, nor were any differences in the sugar composition of cell wall polysaccharides detected.', 'pubmed': 18199744}, {'locus': 'AT2G03720', 'germplasm': 
# ...

# %%
#now, I am going to check the content of the locusgene table

import pymysql.cursors

connection = pymysql.connect(host='localhost',
                             user='root',
                             password='root',
                             db='germplasms',
                             charset='utf8mb4',  # note utf8... this is important for unusual characters!
                             cursorclass=pymysql.cursors.DictCursor,
                            #autocommit=True
                            )

connection.autocommit(True)



try:
    with connection.cursor() as cursor:
            
            sql = "SELECT * from locusgene" #it will give all data inside locusgene table
            cursor.execute(sql) 
            results = cursor.fetchall() #cursor fetchall is a list, so the content of the locusgene will be given as a list 
            print(results)
            elements = len(results)
            print(elements)
            #connection.commit()       
    
finally:
    print("")
    connection.close()
# Out:
# [{'locus': 'AT1G01040', 'gene': 'DCL1', 'protein_length': 332}, {'locus': 'AT1G01060', 'gene': 'LHY', 'protein_length': 290}, {'locus': 'AT1G01140', 'gene': 'CIPK9', 'protein_length': 223}, {'locus': 'AT1G01220', 'gene': 'FKGP', 'protein_length': 190}, {'locus': 'AT2G03720', 'gene': 'MRH6', 'protein_length': 189}, {'locus': 'AT2G03800', 'gene': 'GEK1', 'protein_length': 196}, {'locus': 'AT2G04240', 'gene': 'XERICO', 'protein_length': 256}, {'locus': 'AT2G05210', 'gene': 'POT1A', 'protein_length': 221}, {'locus': 'AT3G02130', 'gene': 'RPK2', 'protein_length': 284}, {'locus': 'AT3G02140', 'gene': 'TMAC2', 'protein_length': 300}, {'locus': 'AT3G02230', 'gene': 'RGP1', 'protein_length': 301}, {'locus': 'AT3G02260', 'gene': 'BIG', 'protein_length': 279}, {'locus': 'AT3G02310', 'gene': 'SEP2', 'protein_length': 175}, {'locus': 'AT3G02680', 'gene': 'NBS1', 'protein_length': 190}, {'locus': 'AT3G02850', 'gene': 'SKOR', 'protein_length': 234}, {'locus': 'AT3G02870', 'gene': 'VTC4', 'protein_l
# ...

# %% [markdown]
# PROBLEM 4
#
# 1. First, I am joinging the two tables, using the command select * (select everything) from the 2 tables, where the column locus in germplasm is equal to the column locus in locusgene. Therefore, I will see all the content of the two tables joined by the AGI locus code. Now, I have to write this results to a file.
#
# 2. Second, I am selecting only the records that correspond to the genes 'SKOR' and 'MAA3', showing the full information of these records. For that, I select everything from two tables, but I am establishing 3 conditions with WHERE:
# The first 2 conditions go together, so I use the OR to separate them and brackets to separate them from the third condition. One of these two conditions is that I only want the value from the column 'gene' of 'locusgene' table that are equal to 'SKOR', and the other condition is that I only want the value from the column 'gene' of 'locusgene' table that are equal to 'MAA3'.
# The third conditions is set in relation to the joining of the germplasm and locusgene tables. The column 'locus' in both tables have to be the same.

# %%
connection = pymysql.connect(host='localhost',
                             user='root',
                             password='root',
                             db='germplasms',
                             charset='utf8mb4',  # note utf8... this is important for unusual characters!
                             cursorclass=pymysql.cursors.DictCursor,
                             #autocommit=True
                            )

connection.autocommit(True)



try:
    with connection.cursor() as cursor:
            
            sql = "SELECT * FROM germplasm, locusgene WHERE germplasm.locus = locusgene.locus" #it will give all data inside joined germplasm and locusgene tables
            cursor.execute(sql) 
            results = cursor.fetchall() 
            print(results)
            elements = len(results)
            print(elements)
            #connection.commit()       
    
finally:
    print("")
    connection.close()
# Out:
# [{'locus': 'AT1G01040', 'germplasm': 'CS3828', 'phenotype': 'Increased abundance of miRNA precursors.', 'pubmed': 17369351, 'locusgene.locus': 'AT1G01040', 'gene': 'DCL1', 'protein_length': 332}, {'locus': 'AT1G01060', 'germplasm': 'lhy-101', 'phenotype': 'The mutant plants are hypersensitive to both FRc and Rc light treatments in hypocotyl elongation and exhibits a small reciprocal enlargement in cotyledon area, albeit not statistically significant.', 'pubmed': 16891401, 'locusgene.locus': 'AT1G01060', 'gene': 'LHY', 'protein_length': 290}, {'locus': 'AT1G01140', 'germplasm': 'SALK_058629', 'phenotype': 'hypersensitive to low potassium media', 'pubmed': 17486125, 'locusgene.locus': 'AT1G01140', 'gene': 'CIPK9', 'protein_length': 223}, {'locus': 'AT1G01220', 'germplasm': 'SALK_012400C', 'phenotype': 'fkgp-1 mutants have about 40 times more L-fucose than wild type Arabidopsis plants, but the levels of other monosaccharides do not appear to differ significantly in the mutants. No obvio
# ...

# %%
#problem4-task1


# %sql SELECT * FROM germplasm, locusgene WHERE germplasm.locus = locusgene.locus #selecting everything from germplasm and locusgene tables and joining them through the AGI locus code

#results = %sql SELECT * FROM germplasm, locusgene WHERE germplasm.locus = locusgene.locus
#print(results)
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/mysql
# 0 rows affected.
#  * mysql+pymysql://root:***@127.0.0.1:3306/mysql
# 32 rows affected.
# [('AT1G01040', 'CS3828', 'Increased abundance of miRNA precursors.', 17369351, 'AT1G01040', 'DCL1', 332),
#  ('AT1G01060', 'lhy-101', 'The mutant plants are hypersensitive to both FRc and Rc light treatments in hypocotyl elongation and exhibits a small reciprocal enlargement in cotyledon area, albeit not statistically significant.', 16891401, 'AT1G01060', 'LHY', 290),
#  ('AT1G01140', 'SALK_058629', 'hypersensitive to low potassium media', 17486125, 'AT1G01140', 'CIPK9', 223),
# ...

# %%
#problem4-task2

# %sql SELECT * from germplasm, locusgene WHERE (locusgene.gene = 'SKOR' OR locusgene.gene = 'MAA3') AND germplasm.locus = locusgene.locus
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/mysql
# 2 rows affected.
# [('AT3G02850', 'CS3816', 'The skor-1 mutant is sensitive to toxic cations in addition to K+ depletion.', 17568770, 'AT3G02850', 'SKOR', 234),
#  ('AT4G15570', 'maa3', 'Homozygotes are not recovered. Female gametophyte development is delayed and asynchronous. During fertilization, fusion of polar nuclei does not occur. Polar nuclei nucloeli are smaller than WT.', 18772186, 'AT4G15570', 'MAA3', 294)]

# %%
#problem4-task3

# %%
#problem4-task4


#searching for AGI1: choromosome 1 
locusgene_table.seek(0)
for line in locusgene_table.readlines()[1:34]: #for each line read by readlines() in locusgene table. I specify that only want to read from lines 2 to 34 (because the first one is the header)
    matchObj1 = re.search( r'(AT1G\w*\t)', line)  #match this regular expression, which corresponds to the search of ATxGxxxxxx AGI Locus Code
    if matchObj1: #if there is a match
        AGI1_locusgene = matchObj1.group() #create an object with the matches 
        print(AGI1_locusgene) #print the object 
    else: #otherwise
        print ("") #prints nothing

#average of AGI1s
# %sql SELECT AVG(locusgene.protein_length) FROM locusgene  WHERE locusgene.locus = 'AT1G01040' AND 'AT1G01060' AND 'AT1G01140' AND 'AT1G01220'



#searching for AGI2: choromosome 2
locusgene_table.seek(0)
for line in locusgene_table.readlines()[1:34]: #for each line read by readlines() in locusgene table. I specify that only want to read from lines 2 to 34 (because the first one is the header)
    matchObj2 = re.search( r'AT2G\w*\t', line)  #match this regular expression, which corresponds to the search of ATxGxxxxxx AGI Locus Code
    if matchObj2: #if there is a match
        AGI2_locusgene = matchObj2.group() #create an object with the matches 
        print(AGI2_locusgene) #print the object 
    else: #otherwise
        print ("") #prints nothing

#average of AGI2s
# %sql SELECT AVG(locusgene.protein_length) FROM locusgene  WHERE locusgene.locus = 'AT2G05210' OR 'AT2G05210' OR 'AT2G05210' OR 'AT2G05210'



#searching for AGI3: choromosome 3
locusgene_table.seek(0)
for line in locusgene_table.readlines()[1:34]: #for each line read by readlines() in locusgene table. I specify that only want to read from lines 2 to 34 (because the first one is the header)
    matchObj3 = re.search( r'AT3G\w*\t', line)  #match this regular expression, which corresponds to the search of ATxGxxxxxx AGI Locus Code
    if matchObj3: #if there is a match
        AGI3_locusgene = matchObj3.group() #create an object with the matches 
        print(AGI3_locusgene) #print the object 
    else: #otherwise
        print ("") #prints nothing

#average of AGI3s
# %sql SELECT AVG(locusgene.protein_length) FROM locusgene  WHERE locusgene.locus = 'AT3G02130' OR 'AT3G02140' OR 'AT3G02230' OR 'AT3G02260' OR 'AT3G02310' OR 'AT3G02680' OR 'AT3G02850' OR 'AT3G02870' OR 'AT3G03260'



#searching for AGI4: choromosome 4
locusgene_table.seek(0)
for line in locusgene_table.readlines()[1:34]: #for each line read by readlines() in locusgene table. I specify that only want to read from lines 2 to 34 (because the first one is the header)
    matchObj4 = re.search( r'AT4G\w*\t', line)  #match this regular expression, which corresponds to the search of ATxGxxxxxx AGI Locus Code
    if matchObj4: #if there is a match
        AGI4_locusgene = matchObj4.group() #create an object with the matches 
        print(AGI4_locusgene) #print the object 
    else: #otherwise
        print ("") #prints nothing

#average of AGI4s
# %sql SELECT AVG(locusgene.protein_length) FROM locusgene  WHERE locusgene.locus = 'AT4G14790' OR 'AT4G15210'OR 'AT4G15560' OR 'AT4G15570' OR 'AT4G15802' OR 'AT4G15880' OR 'AT4G16420' OR 'AT4G16480'


#searching for AGI5: choromosome 5
locusgene_table.seek(0)
for line in locusgene_table.readlines()[1:34]: #for each line read by readlines() in locusgene table. I specify that only want to read from lines 2 to 34 (because the first one is the header)
    matchObj5 = re.search( r'AT5G\w*\t', line)  #match this regular expression, which corresponds to the search of ATxGxxxxxx AGI Locus Code
    if matchObj5: #if there is a match
        AGI5_locusgene = matchObj5.group() #create an object with the matches 
        print(AGI5_locusgene) #print the object 
    else: #otherwise
        print ("") #prints nothing

#average of AGI5s
# %sql SELECT AVG(locusgene.protein_length) FROM locusgene WHERE (locusgene.locus = 'AT5G10480' OR 'AT5G10510')
#
# Out:
# AT1G01040
# AT1G01060
# AT1G01140
# AT1G01220
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  * mysql+pymysql://root:***@127.0.0.1:3306/mysql
# 1 rows affected.
#
#
#
#
# AT2G03720
# AT2G03800
# AT2G04240
# AT2G05210
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  * mysql+pymysql://root:***@127.0.0.1:3306/mysql
# 1 rows affected.
#
#
#
#
#
#
#
#
# AT3G02130
# AT3G02140
# AT3G02230
# AT3G02260
# AT3G02310
# AT3G02680
# AT3G02850
# AT3G02870
# AT3G03260
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  * mysql+pymysql://root:***@127.0.0.1:3306/mysql
# 1 rows affected.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# AT4G14790
# AT4G15210
# AT4G15560
# AT4G15570
# AT4G15802
# AT4G15880
# AT4G16420
# AT4G16480
#
#
#
#
#
#
#
#  * mysql+pymysql://root:***@127.0.0.1:3306/mysql
# 1 rows affected.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# AT5G10480
# AT5G10510
# AT5G11110
# AT5G11260
# AT5G11510
# AT5G12200
# AT5G13290
#  * mysql+pymysql://root:***@127.0.0.1:3306/mysql
# 1 rows affected.
# ...
